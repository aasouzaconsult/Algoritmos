# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Visão Geral do Dataframe
#
#
# *   Qual o tamanho do dataset (MB, GB)
# *   Quantidade de linhas duplicadas.
# *   Quantidade de linhas do dataframe
# *   Quantidade de linhas por colunas
# *   O tipo de dado de cada coluna
# *   Quais colunas contém missi values
# *   Qual a distribuiçao das colunas numéricas

# %% [markdown]
# **Importa o pandas e carrega o dataframe**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/Inspecionando Datasets com o Pandas Profiling/diabetes.csv')

# %%
df.head(50)
# Out:
#     Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0             6      148             72  ...                     0.627   50        1
# 1             1       85             66  ...                     0.351   31        0
# 2             8      183             64  ...                     0.672   32        1
# 3             1       89             66  ...                     0.167   21        0
# 4             0      137             40  ...                     2.288   33        1
# 5             5      116             74  ...                     0.201   30        0
# 6             3       78             50  ...                     0.248   26        1
# 7            10      115              0  ...                     0.134   29        0
# 8             2      197             70  ...                     0.158   53        1
# 9             8      125             96  ...                     0.232   54        1
# ...

# %% [markdown]
# **Install pandas profiling**

# %%
# !pip install -U pandas-profiling
# Out:
# Requirement already up-to-date: pandas-profiling in /usr/local/lib/python3.6/dist-packages (2.4.0)
# ...

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title='Profiling Diabets',html={'style':{'full_width':True}})

# %% [markdown]
# **Exibe o Relatório diretamente no Jupyter Notebook**

# %%
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Escreve relatório para o drive**

# %%
profile.to_file(output_file="/content/drive/My Drive/Inspecionando Datasets com o Pandas Profiling/dataframe_report.html")

# %% [markdown]
# **Datasets muito grandes**

# %%
profile = ProfileReport(df, minimal=True)

# %%
 profile.to_notebook_iframe()
