# %% [markdown]
# # Web Scraping e pré-processamento
# **Web Scraping**: o ato de baixar automaticamente os dados de uma página web e extrair informações muito específicas dela. As informações extraídas podem ser armazenadas praticamente em qualquer lugar (banco de dados, arquivo, etc.). Web scraping, também conhecido como Extração de Dados da Web, é uma maneira automatizada de extrair informações/conteúdo usando bots, conhecidos como scrapers. Aqui, as informações podem ser usadas para replicar em algum outro site ou podem ser usadas para análise de dados. ([fonte](http://datascienceacademy.com.br/blog/web-scraping-e-web-crawling-sao-legais-ou-ilegais/))
#
# **Pré-processamento**: Tratamento dos dados (remoção de stop words, pontuação, tokeninação...)

# %% [markdown]
# ## Demonstração

# %% [markdown]
# ### Web-Scraping

# %% [markdown]
# Importando as Bibliotecas necessárias

# %%
import requests
from bs4 import BeautifulSoup
import json
import pickle

# %% [markdown]
# Criando um vetor para armazenar os dados (no caso, notícias)

# %%
X = []

# %% [markdown]
# Função para baixar as notícias
# - utilizaremos a biblioteca `BeautifulSoup`

# %%
def print_headlines_tec(response_text):
    soup = BeautifulSoup(response_text, 'lxml')
    headlines   = soup.find_all('div', attrs={"itemprop": "articleBody"})

    for headline in headlines:
        X.append(headline.text)

# %% [markdown]
# Essa função, visita a URL abaixo, e baixa as notícias, como a destacada a seguir...

# %% [markdown]
# ![texto alternativo](https://blogdozouza.files.wordpress.com/2020/08/webscrap.png)

# %%
# URL que iremos utilizar...
url = 'https://inshorts.com/en/read/technology'

# %% [markdown]
# Aplicando...

# %%
response = requests.get(url)
print_headlines_tec(response.text)

# %% [markdown]
# Verificando os dados importados

# %%
X
# Out:
# ['Facebook-parent Meta Platforms has announced that it would lay off another 10,000 employees in second round of firing, four months after laying off 11,000 employees. "[We also] expect to close around 5,000 additional open roles that we haven\'t yet hired," Meta CEO Mark Zuckerberg announced. "This will be tough and there\'s no way around that," he added.',
#  'Nokia CEO Pekka Lundmark tweeted pictures of his meeting with Prime Minister Narendra Modi on Monday and said it was "a privilege to meet with" him. They discussed the next phase of digital transformation and how Nokia intends to support India\'s 6G ambitions, Lundmark said. Meanwhile, PM Modi responded to Lundmark\'s tweet and said, "[It was] a fruitful meeting."',
#  "The government is reportedly planning to introduce new security rules that would force smartphone makers to let users remove pre-installed apps from phones. According to a Reuters report, the government may also mandate screening of major operating system updates. The new rules are expected to affect the smartphones' launch timelines and lead to losses for Samsung, Xiaomi, Vivo and Apple.",
#  "Microsoft has signed a 10-year deal with cloud gaming platform Boosteroid to share Xbox PC games with the firm. Boosteroid, which has its software development team in Ukraine, will also get access to titles like 'Call of Duty' once Microsoft acquires Activision Blizzard. Microsoft earlier signed similar deals with Nintendo and NVIDIA as it seeks regulators' approval for Activision acquisition.",
#  "The Competition Commission of India (CCI) told NCLAT companies which refused to sign Google's Android contracts and instead developed their own apps became extinct. CCI also argued that Google's agreements such as Mobile Application Distribution Agreement (MADA), among others were anti-competitive. The NCLAT is hearing a case over alleged abuse of Google's dominant position in the Android market.",
#  'Meta CEO Mark Zuckerberg and its employees were aware of the harmful effects of their platforms on young children and teenagers but disregarded the information, as per a lawsuit filed in the US over social media addiction. The lawsuit cited a Meta employee as saying that the company tries to "maximize the number of times" a user opens Instagram.',
#  'Finance Minister Nirmala Sitharaman told the Parliament that cryptocurrency-related crimes have amounted to ₹953.7 crore so far. She added that with virtual assets being increasingly used for money laundering and terror financing, the Financial Action Task Force (FATF) has made several amendments. Sitharaman also said the FATF adopted several methods to prevent illegitimate activities from crypto.',
#  'Tesla CEO Elon Musk on Tuesday denied a report that claimed his company is ending tie-up on battery supplies with China\'s electric vehicle and battery maker BYD. "[The] media report is false. Relations between Tesla and BYD are positive," Musk said. BYD also told Reuters that the report "is not in line with the actual situation".',
#  "Billionaire Stephen Schwarzman's private equity firm Blackstone will acquire event software provider Cvent for $4.6 billion. This comes after an earlier deal of $3.9 billion was rejected by Cvent for being too low, Reuters reported. Founded in 1999 by Reggie Aggarwal, Cvent was acquired by Vista Equity Partners for $1.65 billion in 2016.",
#  'Google on Tuesday unveiled ChatGPT-like AI features for Gmail and Docs that will allow users to instantly generate drafts on any topic. Users will also be able to set the tone of the drafts. Google also announced generative AI features for other Workspace apps including Meet and Slides that will capture notes and generate images, among other things.',
#  'Meta, the parent company of Instagram and Facebook, is ending support for non-fungible tokens (NFTs) on its platforms amid decline in crypto market. Meta began testing the feature in May 2022. "We\'re winding down digital collectibles (NFTs) for now to focus on other ways to support creators, people, and businesses," said Stephane Kasriel, Meta\'s Head of Commerce and Financial Technologies.',
#  'Microsoft Cloud chief Scott Guthrie told Bloomberg that the company invested hundreds of millions of dollars to build a supercomputer for ChatGPT maker OpenAI. Microsoft linked together thousands of NVIDIA graphic chips to build the supercomputer. Another Microsoft executive Nidhi Chappell said the project made ChatGPT possible, and there will be more AI models that will come out of it.',
#  'YouTube videos containing links to malware that can steal user data have seen up to 300% jump since November 2022, cybersecurity firm CloudSEK reported. The videos mostly pose as tutorials for downloading cracked versions of licensed software products like Adobe Photoshop and AutoCAD, the report noted. Such videos are also using AI-generated personas to lure viewers, it added.',
#  'Meta has announced putting on hold the bonus for creators of Reels on Facebook, Business Insider reported. The company said it is focusing on creating new features to make it easier for creators to build and grow their audience. The programme was introduced in 2021. However, the move will hit all Reels creators on Facebook and US-based creators on Instagram. \n',
#  'Amazon on Tuesday said it plans to launch its first internet satellites in the first half of 2024 and offer initial services shortly after. It also revealed designs for terminals that will connect customers with the service. Under Project Kuiper, Amazon aims to build a network of 3,236 satellites in low Earth orbit with an investment of over $10 billion.',
#  'Anthropic, a startup founded by former OpenAI executives and backed by Google, has launched an AI chatbot called Claude that competes with OpenAI\'s ChatGPT. Claude can perform several tasks including answering queries and writing codes based on text prompts. "Claude is much less likely to produce harmful outputs, easier to converse with and more steerable," Anthropic stated.',
#  'Shareholders of collapsed Signature Bank have sued the bank and its former CEO, CFO and COO in the US. The proposed class action lawsuit accuses the bank of fraudulently claiming it was financially strong just three days before it was seized by a state regulator. Signature Bank, which had clients in real estate and crypto sector, was closed on Sunday.',
#  "Microsoft has reportedly laid off its entire team responsible for the ethical and sustainable outcome of its artificial intelligence development. As per the Platformer, the job cuts are part of the company's recent layoffs that affected nearly 10,000 employees. The move comes amid Microsoft's push to become an AI leader, with the company investing billions of dollars in ChatGPT-maker OpenAI.",
#  'Samsung has reportedly laid off 3% of its workforce (around 30 employees) at its US semiconductor subsidiary Device Solutions America (DSA). As per a report, the company cited uncertain economic conditions as the reason for the layoffs. Notably, Samsung reported a 96.9% year-on-year decline in operating profits in its semiconductor division in Q4 2022.',
#  "IIT Madras Director V Kamakoti said, as part of MeitY's Bhashini initiative, the institute is developing a nine-language enabled text-to-text translator to bridge the language gap in India. He said ultimately the aim is to develop a text-to-speech translator. He added that over a period of time, the algorithm learns and eventually, the artificial intelligence affects the translation. ",
#  'Amazon and Rivian are in talks to end the exclusivity part of their electric-van deal, after which Rivian will be able to sell to other firms, the WSJ reported citing sources. Under a 2019 agreement, Rivian is required to sell all the vans it manufactures to Amazon. However, Amazon informed Rivian it wanted to buy about 10,000 vans this year.',
#  'Spanish company PLD Space is set to launch its maiden rocket, which will be the first private reusable rocket from Western Europe, later this year. \'Miura 1\' has a 100-kg cargo capacity and can be used to carry zero-gravity experiments. "[It]...will put Spain at the vanguard of this...potent industry," Spanish PM Pedro Sanchez said during Miura 1\'s unveiling on Saturday.',
#  'The first semiconductor fabrication unit will be declared in the next few weeks, IT Minister Ashwini Vaishnaw said on Tuesday. He added that with the kind of interest many stakeholders and other semiconductor participants are showing, India "should see a vibrant semiconductor industry in the next three-four years". India\'s electronics manufacturing industry is close to $87 billion, he noted.',
#  "The Income Tax Department has reportedly imposed a ₹549-crore tax demand notice on Amazon's cloud unit Amazon Web Services (AWS). As per the Economic Times, AWS was allegedly charging a fee for providing services to Indian entities but not paying tax on it. The department has raised a ₹190.85 crore tax demand for FY15 and ₹358.27 crore for FY17.",
#  'UK Security Minister Tom Tugendhat said he asked Britain\'s National Cyber Security Centre to conduct an "important" investigation into Chinese social media app TikTok\'s ownership. He added that many people consider TikTok a news source and it is important to know who owns a news source. He, however, didn\'t specify whether TikTok would be banned from UK government mobile devices. ']

# %% [markdown]
# ### Pré-Processamento

# %% [markdown]
# Importando as Bibliotecas necessárias

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from string import punctuation

# %% [markdown]
# Instanciando `Stopword` e `Stemmer`

# %%
stopword = stopwords.words('english')
snowball_stemmer = SnowballStemmer('english')

# %% [markdown]
# Criação da Função para Remoção de Pontuação

# %%
def strip_punctuation(s):
        return ''.join(c for c in s if c not in punctuation)

# %% [markdown]
# #### Realizando a Limpeza...

# %%
# Cria uma variável auxiliar Xa que irá receber X
Xa = []
Xa = X

# Cria uma X vazia
X = []

# %%
for i in range(0,len(Xa)):
        text               = strip_punctuation(Xa[i]) # remove pontuacao
        text               = ''.join(c for c in text if not c.isdigit()) # remove numeros
        word_tokens        = nltk.word_tokenize(text.lower()) # processo de tokenização
        removing_stopwords = [word for word in word_tokens if word not in stopword] # remove stopwords
        stemmed_word       = [snowball_stemmer.stem(word) for word in removing_stopwords] # aplica stemmed
        X.append(stemmed_word)

# %% [markdown]
# Visualizando o tratamento dos dados

# %%
# Variável Auxiliar (lendo o primeiro registro)
Xa[0]
# Out:
# 'Facebook-parent Meta Platforms has announced that it would lay off another 10,000 employees in second round of firing, four months after laying off 11,000 employees. "[We also] expect to close around 5,000 additional open roles that we haven\'t yet hired," Meta CEO Mark Zuckerberg announced. "This will be tough and there\'s no way around that," he added.'

# %%
# Variável X tratada (lendo o primeiro registro)
X[0]
# Out:
# ['facebookpar',
#  'meta',
#  'platform',
#  'announc',
#  'would',
#  'lay',
#  'anoth',
#  'employe',
#  'second',
#  'round',
#  'fire',
#  'four',
#  'month',
#  'lay',
#  'employe',
#  'also',
#  'expect',
#  'close',
#  'around',
#  'addit',
#  'open',
#  'role',
#  'havent',
#  'yet',
#  'hire',
#  'meta',
#  'ceo',
#  'mark',
#  'zuckerberg',
#  'announc',
#  'tough',
#  'there',
#  'way',
#  'around',
#  'ad']

# %% [markdown]
# Vendo todos os registros de X

# %%
X
# Out:
# [['facebookpar',
#   'meta',
#   'platform',
#   'announc',
#   'would',
#   'lay',
#   'anoth',
#   'employe',
#   'second',
#   'round',
#   'fire',
#   'four',
#   'month',
#   'lay',
#   'employe',
#   'also',
#   'expect',
#   'close',
#   'around',
#   'addit',
#   'open',
#   'role',
#   'havent',
#   'yet',
#   'hire',
#   'meta',
#   'ceo',
#   'mark',
#   'zuckerberg',
#   'announc',
#   'tough',
#   'there',
#   'way',
#   'around',
#   'ad'],
#  ['nokia',
#   'ceo',
#   'pekka',
#   'lundmark',
#   'tweet',
#   'pictur',
#   'meet',
#   'prime',
#   'minist',
#   'narendra',
#   'modi',
#   'monday',
#   'said',
#   'privileg',
#   'meet',
#   'discuss',
#   'next',
#   'phase',
#   'digit',
#   'transform',
#   'nokia',
#   'intend',
#   'support',
#   'india',
#   'g',
#   'ambit',
#   'lundmark',
#   'said',
#   'meanwhil',
#   'pm',
#   'modi',
#   'respond',
#   'lundmark',
#   'tweet',
#   'said',
#   'fruit',
#   'meet'],
#  ['govern',
#   'report',
#   'plan',
#   'introduc',
#   'new',
#   'secur',
#   'rule',
#   'would',
#   'forc',
#   'smartphon',
#   'maker',
#   'let',
#   'user',
#   'remov',
#   'preinstal',
#   'app',
#   'phone',
#   'accord',
#   'reuter',
#   'report',
#   'govern',
#   'may',
#   'also',
#   'mandat',
#   'screen',
#   'major',
#   'oper',
#   'system',
#   'updat',
#   'new',
#   'rule',
#   'expect',
#   'affect',
#   'smartphon',
#   'launch',
#   'timelin',
#   'lead',
#   'loss',
#   'samsung',
#   'xiaomi',
#   'vivo',
#   'appl'],
#  ['microsoft',
#   'sign',
#   'year',
#   'deal',
#   'cloud',
#   'game',
#   'platform',
#   'boosteroid',
#   'share',
#   'xbox',
#   'pc',
#   'game',
#   'firm',
#   'boosteroid',
#   'softwar',
#   'develop',
#   'team',
#   'ukrain',
#   'also',
#   'get',
#   'access',
#   'titl',
#   'like',
#   'call',
#   'duti',
#   'microsoft',
#   'acquir',
#   'activis',
#   'blizzard',
#   'microsoft',
#   'earlier',
#   'sign',
#   'similar',
#   'deal',
#   'nintendo',
#   'nvidia',
#   'seek',
#   'regul',
#   'approv',
#   'activis',
#   'acquisit'],
#  ['competit',
#   'commiss',
#   'india',
#   'cci',
#   'told',
#   'nclat',
#   'compani',
#   'refus',
#   'sign',
#   'googl',
#   'android',
#   'contract',
#   'instead',
#   'develop',
#   'app',
#   'becam',
#   'extinct',
#   'cci',
#   'also',
#   'argu',
#   'googl',
#   'agreement',
#   'mobil',
#   'applic',
#   'distribut',
#   'agreement',
#   'mada',
#   'among',
#   'other',
#   'anticompetit',
#   'nclat',
#   'hear',
#   'case',
#   'alleg',
#   'abus',
#   'googl',
#   'domin',
#   'posit',
#   'android',
#   'market'],
#  ['meta',
#   'ceo',
#   'mark',
#   'zuckerberg',
#   'employe',
#   'awar',
#   'harm',
#   'effect',
#   'platform',
#   'young',
#   'children',
#   'teenag',
#   'disregard',
#   'inform',
#   'per',
#   'lawsuit',
#   'file',
#   'us',
#   'social',
#   'media',
#   'addict',
#   'lawsuit',
#   'cite',
#   'meta',
#   'employe',
#   'say',
#   'compani',
#   'tri',
#   'maxim',
#   'number',
#   'time',
#   'user',
#   'open',
#   'instagram'],
#  ['financ',
#   'minist',
#   'nirmala',
#   'sitharaman',
#   'told',
#   'parliament',
#   'cryptocurrencyrel',
#   'crime',
#   'amount',
#   '₹',
#   'crore',
#   'far',
#   'ad',
#   'virtual',
#   'asset',
#   'increas',
#   'use',
#   'money',
#   'launder',
#   'terror',
#   'financ',
#   'financi',
#   'action',
#   'task',
#   'forc',
#   'fatf',
#   'made',
#   'sever',
#   'amend',
#   'sitharaman',
#   'also',
#   'said',
#   'fatf',
#   'adopt',
#   'sever',
#   'method',
#   'prevent',
#   'illegitim',
#   'activ',
#   'crypto'],
#  ['tesla',
#   'ceo',
#   'elon',
#   'musk',
#   'tuesday',
#   'deni',
#   'report',
#   'claim',
#   'compani',
#   'end',
#   'tieup',
#   'batteri',
#   'suppli',
#   'china',
#   'electr',
#   'vehicl',
#   'batteri',
#   'maker',
#   'byd',
#   'media',
#   'report',
#   'fals',
#   'relat',
#   'tesla',
#   'byd',
#   'posit',
#   'musk',
#   'said',
#   'byd',
#   'also',
#   'told',
#   'reuter',
#   'report',
#   'line',
#   'actual',
#   'situat'],
#  ['billionair',
#   'stephen',
#   'schwarzman',
#   'privat',
#   'equiti',
#   'firm',
#   'blackston',
#   'acquir',
#   'event',
#   'softwar',
#   'provid',
#   'cvent',
#   'billion',
#   'come',
#   'earlier',
#   'deal',
#   'billion',
#   'reject',
#   'cvent',
#   'low',
#   'reuter',
#   'report',
#   'found',
#   'reggi',
#   'aggarw',
#   'cvent',
#   'acquir',
#   'vista',
#   'equiti',
#   'partner',
#   'billion'],
#  ['googl',
#   'tuesday',
#   'unveil',
#   'chatgptlik',
#   'ai',
#   'featur',
#   'gmail',
#   'doc',
#   'allow',
#   'user',
#   'instant',
#   'generat',
#   'draft',
#   'topic',
#   'user',
#   'also',
#   'abl',
#   'set',
#   'tone',
#   'draft',
#   'googl',
#   'also',
#   'announc',
#   'generat',
#   'ai',
#   'featur',
#   'workspac',
#   'app',
#   'includ',
#   'meet',
#   'slide',
#   'captur',
#   'note',
#   'generat',
#   'imag',
#   'among',
#   'thing'],
#  ['meta',
#   'parent',
#   'compani',
#   'instagram',
#   'facebook',
#   'end',
#   'support',
#   'nonfung',
#   'token',
#   'nfts',
#   'platform',
#   'amid',
#   'declin',
#   'crypto',
#   'market',
#   'meta',
#   'began',
#   'test',
#   'featur',
#   'may',
#   'wind',
#   'digit',
#   'collect',
#   'nfts',
#   'focus',
#   'way',
#   'support',
#   'creator',
#   'peopl',
#   'busi',
#   'said',
#   'stephan',
#   'kasriel',
#   'meta',
#   'head',
#   'commerc',
#   'financi',
#   'technolog'],
#  ['microsoft',
#   'cloud',
#   'chief',
#   'scott',
#   'guthri',
#   'told',
#   'bloomberg',
#   'compani',
#   'invest',
#   'hundr',
#   'million',
#   'dollar',
#   'build',
#   'supercomput',
#   'chatgpt',
#   'maker',
#   'openai',
#   'microsoft',
#   'link',
#   'togeth',
#   'thousand',
#   'nvidia',
#   'graphic',
#   'chip',
#   'build',
#   'supercomput',
#   'anoth',
#   'microsoft',
#   'execut',
#   'nidhi',
#   'chappel',
#   'said',
#   'project',
#   'made',
#   'chatgpt',
#   'possibl',
#   'ai',
#   'model',
#   'come'],
#  ['youtub',
#   'video',
#   'contain',
#   'link',
#   'malwar',
#   'steal',
#   'user',
#   'data',
#   'seen',
#   'jump',
#   'sinc',
#   'novemb',
#   'cybersecur',
#   'firm',
#   'cloudsek',
#   'report',
#   'video',
#   'most',
#   'pose',
#   'tutori',
#   'download',
#   'crack',
#   'version',
#   'licens',
#   'softwar',
#   'product',
#   'like',
#   'adob',
#   'photoshop',
#   'autocad',
#   'report',
#   'note',
#   'video',
#   'also',
#   'use',
#   'aigener',
#   'persona',
#   'lure',
#   'viewer',
#   'ad'],
#  ['meta',
#   'announc',
#   'put',
#   'hold',
#   'bonus',
#   'creator',
#   'reel',
#   'facebook',
#   'busi',
#   'insid',
#   'report',
#   'compani',
#   'said',
#   'focus',
#   'creat',
#   'new',
#   'featur',
#   'make',
#   'easier',
#   'creator',
#   'build',
#   'grow',
#   'audienc',
#   'programm',
#   'introduc',
#   'howev',
#   'move',
#   'hit',
#   'reel',
#   'creator',
#   'facebook',
#   'usbas',
#   'creator',
#   'instagram'],
#  ['amazon',
#   'tuesday',
#   'said',
#   'plan',
#   'launch',
#   'first',
#   'internet',
#   'satellit',
#   'first',
#   'half',
#   'offer',
#   'initi',
#   'servic',
#   'short',
#   'also',
#   'reveal',
#   'design',
#   'termin',
#   'connect',
#   'custom',
#   'servic',
#   'project',
#   'kuiper',
#   'amazon',
#   'aim',
#   'build',
#   'network',
#   'satellit',
#   'low',
#   'earth',
#   'orbit',
#   'invest',
#   'billion'],
#  ['anthrop',
#   'startup',
#   'found',
#   'former',
#   'openai',
#   'execut',
#   'back',
#   'googl',
#   'launch',
#   'ai',
#   'chatbot',
#   'call',
#   'claud',
#   'compet',
#   'openai',
#   'chatgpt',
#   'claud',
#   'perform',
#   'sever',
#   'task',
#   'includ',
#   'answer',
#   'queri',
#   'write',
#   'code',
#   'base',
#   'text',
#   'prompt',
#   'claud',
#   'much',
#   'less',
#   'like',
#   'produc',
#   'harm',
#   'output',
#   'easier',
#   'convers',
#   'steerabl',
#   'anthrop',
#   'state'],
#  ['sharehold',
#   'collaps',
#   'signatur',
#   'bank',
#   'su',
#   'bank',
#   'former',
#   'ceo',
#   'cfo',
#   'coo',
#   'us',
#   'propos',
#   'class',
#   'action',
#   'lawsuit',
#   'accus',
#   'bank',
#   'fraudul',
#   'claim',
#   'financi',
#   'strong',
#   'three',
#   'day',
#   'seiz',
#   'state',
#   'regul',
#   'signatur',
#   'bank',
#   'client',
#   'real',
#   'estat',
#   'crypto',
#   'sector',
#   'close',
#   'sunday'],
#  ['microsoft',
#   'report',
#   'laid',
#   'entir',
#   'team',
#   'respons',
#   'ethic',
#   'sustain',
#   'outcom',
#   'artifici',
#   'intellig',
#   'develop',
#   'per',
#   'platform',
#   'job',
#   'cut',
#   'part',
#   'compani',
#   'recent',
#   'layoff',
#   'affect',
#   'near',
#   'employe',
#   'move',
#   'come',
#   'amid',
#   'microsoft',
#   'push',
#   'becom',
#   'ai',
#   'leader',
#   'compani',
#   'invest',
#   'billion',
#   'dollar',
#   'chatgptmak',
#   'openai'],
#  ['samsung',
#   'report',
#   'laid',
#   'workforc',
#   'around',
#   'employe',
#   'us',
#   'semiconductor',
#   'subsidiari',
#   'devic',
#   'solut',
#   'america',
#   'dsa',
#   'per',
#   'report',
#   'compani',
#   'cite',
#   'uncertain',
#   'econom',
#   'condit',
#   'reason',
#   'layoff',
#   'notabl',
#   'samsung',
#   'report',
#   'yearonyear',
#   'declin',
#   'oper',
#   'profit',
#   'semiconductor',
#   'divis',
#   'q'],
#  ['iit',
#   'madra',
#   'director',
#   'v',
#   'kamakoti',
#   'said',
#   'part',
#   'meiti',
#   'bhashini',
#   'initi',
#   'institut',
#   'develop',
#   'ninelanguag',
#   'enabl',
#   'texttotext',
#   'translat',
#   'bridg',
#   'languag',
#   'gap',
#   'india',
#   'said',
#   'ultim',
#   'aim',
#   'develop',
#   'texttospeech',
#   'translat',
#   'ad',
#   'period',
#   'time',
#   'algorithm',
#   'learn',
#   'eventu',
#   'artifici',
#   'intellig',
#   'affect',
#   'translat'],
#  ['amazon',
#   'rivian',
#   'talk',
#   'end',
#   'exclus',
#   'part',
#   'electricvan',
#   'deal',
#   'rivian',
#   'abl',
#   'sell',
#   'firm',
#   'wsj',
#   'report',
#   'cite',
#   'sourc',
#   'agreement',
#   'rivian',
#   'requir',
#   'sell',
#   'van',
#   'manufactur',
#   'amazon',
#   'howev',
#   'amazon',
#   'inform',
#   'rivian',
#   'want',
#   'buy',
#   'van',
#   'year'],
#  ['spanish',
#   'compani',
#   'pld',
#   'space',
#   'set',
#   'launch',
#   'maiden',
#   'rocket',
#   'first',
#   'privat',
#   'reusabl',
#   'rocket',
#   'western',
#   'europ',
#   'later',
#   'year',
#   'miura',
#   'kg',
#   'cargo',
#   'capac',
#   'use',
#   'carri',
#   'zerograv',
#   'experi',
#   'itwil',
#   'put',
#   'spain',
#   'vanguard',
#   'thispot',
#   'industri',
#   'spanish',
#   'pm',
#   'pedro',
#   'sanchez',
#   'said',
#   'miura',
#   'unveil',
#   'saturday'],
#  ['first',
#   'semiconductor',
#   'fabric',
#   'unit',
#   'declar',
#   'next',
#   'week',
#   'minist',
#   'ashwini',
#   'vaishnaw',
#   'said',
#   'tuesday',
#   'ad',
#   'kind',
#   'interest',
#   'mani',
#   'stakehold',
#   'semiconductor',
#   'particip',
#   'show',
#   'india',
#   'see',
#   'vibrant',
#   'semiconductor',
#   'industri',
#   'next',
#   'threefour',
#   'year',
#   'india',
#   'electron',
#   'manufactur',
#   'industri',
#   'close',
#   'billion',
#   'note'],
#  ['incom',
#   'tax',
#   'depart',
#   'report',
#   'impos',
#   '₹crore',
#   'tax',
#   'demand',
#   'notic',
#   'amazon',
#   'cloud',
#   'unit',
#   'amazon',
#   'web',
#   'servic',
#   'aw',
#   'per',
#   'econom',
#   'time',
#   'aw',
#   'alleg',
#   'charg',
#   'fee',
#   'provid',
#   'servic',
#   'indian',
#   'entiti',
#   'pay',
#   'tax',
#   'depart',
#   'rais',
#   '₹',
#   'crore',
#   'tax',
#   'demand',
#   'fy',
#   '₹',
#   'crore',
#   'fy'],
#  ['uk',
#   'secur',
#   'minist',
#   'tom',
#   'tugendhat',
#   'said',
#   'ask',
#   'britain',
#   'nation',
#   'cyber',
#   'secur',
#   'centr',
#   'conduct',
#   'import',
#   'investig',
#   'chines',
#   'social',
#   'media',
#   'app',
#   'tiktok',
#   'ownership',
#   'ad',
#   'mani',
#   'peopl',
#   'consid',
#   'tiktok',
#   'news',
#   'sourc',
#   'import',
#   'know',
#   'own',
#   'news',
#   'sourc',
#   'howev',
#   'didnt',
#   'specifi',
#   'whether',
#   'tiktok',
#   'would',
#   'ban',
#   'uk',
#   'govern',
#   'mobil',
#   'devic']]

# %% [markdown]
# ## Referências
# - (SOUZA, 2019) SOUZA, ANTONIO ALEX DE. LUPPAR NEWS-REC: UM RECOMENDADOR INTELIGENTE DE NOTÍCIAS. 2019. 95 f. Dissertação (Mestrado Acadêmico em Computação) – Universidade Estadual do Ceará, , 2019. Disponível em: <http://siduece.uece.br/siduece/trabalhoAcademicoPublico.jsf?id=93501> Acesso em: 27 de fevereiro de 2020
#
# - Computer on the beach - Florianópolis - SC ([Artigo](https://blogdozouza.files.wordpress.com/2023/03/computer-on-the-beach-2018-aicn.pdf))
#
# - Classificação de Notícias Curtas usando ML ([Medium Blog - Alex Souza](https://medium.com/blog-do-zouza/classifica%C3%A7%C3%A3o-de-not%C3%ADcias-usando-aprendizado-de-m%C3%A1quina-aeeb9b6efe61))
